# %% [markdown]
# # Simple Naive Bayes

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from sklearn.model_selection import train_test_split

from math import sqrt
from math import pi
from math import exp

from sklearn.metrics import accuracy_score

# %%
import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

body = 'https://github.com/IBM/skillsnetwork/blob/master/coursera_ml/naive_bayes/gender_height_weight.csv'
body = 'gender_height_weight.csv'

dataDF = pd.read_csv(body)
data = dataDF.to_numpy()

# %%
data
# Out:
# array([[  1,  67, 150],
#        [  0,  67, 140],
#        [  1,  67, 100],
#        ...,
#        [  0,  75, 220],
#        [  0,  76, 178],
#        [  1,  67, 130]])

# %%
features = data[:,[1,2]]
labels = data[:,0]

f, ax1 = plt.subplots(1, 1, figsize=(7,7))

ax1.scatter(features[:,0], features[:,1], c=labels, cmap=plt.cm.bwr)        
ax1.grid(True)

plt.ylabel("Weight (lbs)", fontsize=16)
plt.xlabel("Height (inches)", fontsize=16)


recs = []
class_colours=["r","b"]
for i in range(2):
    recs.append(mpatches.Rectangle((0,0),1,1,fc=class_colours[i]))
plt.legend(recs,["F","M"],loc=1)

# %%
features = data[:,[1,2]]
labels = data[:,0]

features_train, features_test, labels_train, labels_test = train_test_split(features,
                                                                            labels, test_size=0.1,
                                                                            random_state = 100)

# %%
def getPriors(labels):
    priors = {}
    for className in labels:
        N = labels.size
        class_occurrence = (labels == className).sum()
        priors[className] = class_occurrence/N
    return priors

priors = getPriors(labels_train)

# %%
priors
# Out:
# {0: 0.5085022445925724, 1: 0.4914977554074276}

# %%
def fit(features, labels):
    uniqueClasses = np.unique(labels)
    coeffs = {}
    for className in uniqueClasses:
      featuresInClass = features[labels == className]
      statsInClass = [(np.mean(feature), np.std(feature)) for feature in zip(*featuresInClass)]            
      coeffs[className] = statsInClass    
    
    return coeffs

model = fit(features_train, labels_train)

# %%
model
# Out:
# {0: [(69.59657570893526, 3.3527911026371027),
#   (163.66238630283573, 38.52142167903383)],
#  1: [(64.43011347910324, 3.000581346637603),
#   (132.66731248270136, 38.37250271665388)]}

# %% [markdown]
# For males: mean_height, std_height = (69.59657570893526, 3.3527911026371027)
# For females: mean_weight, std_weight = (132.66731248270136, 38.37250271665388)

# %%
def getLikelihood(x, featureIndex, model, className):
    classStats = model[className]
    mean = classStats[featureIndex][0]
    std  = classStats[featureIndex][1]
    f = (1/(sqrt(2*pi*pow(std,2))) * exp(-pow((x-mean),2)/(2*pow(std,2))))
    return f

def getPosterior(x, model, priors):
    posteriors = {}
    for className in priors:
        p = priors[className]
        for featureIndex in range(x.size):
            p = p * (getLikelihood (x[featureIndex], featureIndex, model, className))
        posteriors[className] = p
    return posteriors

# %% [markdown]
# A New Observation

# %%
x = np.array([59])

# %%
#featureIndex = 0, height
#className = 0, males
getLikelihood(x, 0, model, 0)
# Out:
# 0.0008061935595272527

# %%
getLikelihood(x, 0, model, 1)
# Out:
# 0.02585559243089853

# %% [markdown]
# The likelihood of height=59, coming from a female is 0.025

# %%
def classify(x, model, priors):
    posteriors = getPosterior(x, model, priors)
    print('x = {}'.format(x))
    print('model (same) = {}'.format(model))
    print('Prior (same) = {}'.format(priors))
    print('Posteriors = {}'.format(priors))
    print('Prediction = {}'.format(max(posteriors, key=lambda key: posteriors[key])))
    return max(posteriors, key=lambda key: posteriors[key])

print('First 5 test values:')
predictions = [classify(x, model, priors) for x in features_test[:5]]
# Out:
# First 5 test values:
# x = [ 70 160]
# model (same) = {0: [(69.59657570893526, 3.3527911026371027), (163.66238630283573, 38.52142167903383)], 1: [(64.43011347910324, 3.000581346637603), (132.66731248270136, 38.37250271665388)]}
# Prior (same) = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Posteriors = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Prediction = 0
# x = [ 69 120]
# model (same) = {0: [(69.59657570893526, 3.3527911026371027), (163.66238630283573, 38.52142167903383)], 1: [(64.43011347910324, 3.000581346637603), (132.66731248270136, 38.37250271665388)]}
# Prior (same) = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Posteriors = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Prediction = 0
# x = [ 61 110]
# model (same) = {0: [(69.59657570893526, 3.3527911026371027), (163.66238630283573, 38.52142167903383)], 1: [(64.43011347910324, 3.000581346637603), (132.66731248270136, 38.37250271665388)]}
# Prior (same) = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Posteriors = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Prediction = 1
# x = [ 72 135]
# model (same) = {0: [(69.59657570893526, 3.3527911026371027), (163.66238630283573, 38.52142167903383)], 1: [(64.43011347910324, 3.000581346637603), (132.66731248270136, 38.37250271665388)]}
# Prior (same) = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Posteriors = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Prediction = 0
# x = [ 68 130]
# model (same) = {0: [(69.59657570893526, 3.3527911026371027), (163.66238630283573, 38.52142167903383)], 1: [(64.43011347910324, 3.000581346637603), (132.66731248270136, 38.37250271665388)]}
# Prior (same) = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Posteriors = {0: 0.5085022445925724, 1: 0.4914977554074276}
# Prediction = 0

# %%
def classify(x, model, priors):
    posteriors = getPosterior(x, model, priors)
    return max(posteriors, key=lambda key: posteriors[key])

predictions = [classify(x, model, priors) for x in features_test]

print("Prediction accuracy: %.2f\n" % accuracy_score(labels_test, predictions))
# Out:
# Prediction accuracy: 0.77

# %% [markdown]
# Naive because it assumes the independence of features
# E.g. for a spam detector, it assumes p(money) is independent from p(win)
# HOWEVER, even through this assumption is quite naive and doesn't hold, generally, the naive Bayesian influence works in practice
